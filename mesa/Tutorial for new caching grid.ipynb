# %% [markdown]
# # Boid Model

# %%
import solara
import mesa

# %%
import numpy as np

from mesa import Agent


class Boid(Agent):
    """A Boid-style flocker agent.

    The agent follows three behaviors to flock:
        - Cohesion: steering towards neighboring agents.
        - Separation: avoiding getting too close to any other agent.
        - Alignment: try to fly in the same direction as the neighbors.

    Boids have a vision that defines the radius in which they look for their
    neighbors to flock with. Their speed (a scalar) and direction (a vector)
    define their movement. Separation is their desired minimum distance from
    any other Boid.
    """

    def __init__(
        self,
        model,
        speed,
        direction,
        vision,
        separation,
        cohere=0.03,
        separate=0.015,
        match=0.05,
    ):
        """Create a new Boid flocker agent.

        Args:
            speed: Distance to move per step.
            direction: numpy vector for the Boid's direction of movement.
            vision: Radius to look around for nearby Boids.
            separation: Minimum distance to maintain from other Boids.
            cohere: the relative importance of matching neighbors' positions
            separate: the relative importance of avoiding close neighbors
            match: the relative importance of matching neighbors' headings
        """
        super().__init__(model)
        self.speed = speed
        self.direction = direction
        self.vision = vision
        self.separation = separation
        self.cohere_factor = cohere
        self.separate_factor = separate
        self.match_factor = match
        self.neighbors = None

    def step(self):
        """Get the Boid's neighbors, compute the new vector, and move accordingly."""
        self.neighbors = self.model.space.get_neighbors(self.pos, self.vision, False)
        n = 0
        match_vector, separation_vector, cohere = np.zeros((3, 2))
        for neighbor in self.neighbors:
            n += 1
            heading = self.model.space.get_heading(self.pos, neighbor.pos)
            cohere += heading
            if self.model.space.get_distance(self.pos, neighbor.pos) < self.separation:
                separation_vector -= heading
            match_vector += neighbor.direction
        n = max(n, 1)
        cohere = cohere * self.cohere_factor
        separation_vector = separation_vector * self.separate_factor
        match_vector = match_vector * self.match_factor
        self.direction += (cohere + separation_vector + match_vector) / n
        self.direction /= np.linalg.norm(self.direction)
        new_pos = self.pos + self.direction * self.speed
        self.model.space.move_agent(self, new_pos)

# %%
"""Flockers.
=============================================================
A Mesa implementation of Craig Reynolds's Boids flocker model.
Uses numpy arrays to represent vectors.
"""

import numpy as np

import mesa

# from .agents import Boid


class BoidFlockers(mesa.Model):
    """Flocker model class. Handles agent creation, placement and scheduling."""

    def __init__(
        self,
        seed=None,
        population=100,
        width=100,
        height=100,
        vision=10,
        speed=1,
        separation=1,
        cohere=0.03,
        separate=0.015,
        match=0.05,
    ):
        """Create a new Flockers model.

        Args:
            population: Number of Boids
            width, height: Size of the space.
            speed: How fast should the Boids move.
            vision: How far around should each Boid look for its neighbors
            separation: What's the minimum distance each Boid will attempt to
                    keep from any other
            cohere, separate, match: factors for the relative importance of
                    the three drives.
        """
        super().__init__(seed=seed)
        self.population = population
        self.vision = vision
        self.speed = speed
        self.separation = separation

        self.space = mesa.space.ContinuousSpace(width, height, True)
        self.factors = {"cohere": cohere, "separate": separate, "match": match}
        self.make_agents()

    def make_agents(self):
        """Create self.population agents, with random positions and starting headings."""
        for _ in range(self.population):
            x = self.random.random() * self.space.x_max
            y = self.random.random() * self.space.y_max
            pos = np.array((x, y))
            direction = np.random.random(2) * 2 - 1
            boid = Boid(
                model=self,
                speed=self.speed,
                direction=direction,
                vision=self.vision,
                separation=self.separation,
                **self.factors,
            )
            self.space.place_agent(boid, pos)

    def step(self):
        self.agents.shuffle_do("step")

# %% [markdown]
# # Instantiating Model

# %%
model = BoidFlockers(100, 100, 100, speed=5, vision=5, separation=1)

# %%
from mesa.cacheable_model import CacheableModel
parameters = ['unique_id', 'pos', 'direction', 'vision', 'speed']
cacheable_model = CacheableModel(model, "output_dir", 100, 100, condition_function=None)
for i in range(100):
    cacheable_model.model.step()
    cacheable_model.cache_grid_data(parameters)

# %%
import pyarrow.parquet as pq

# Specify the path to your Parquet file
parquet_file_path = 'output_dir/grid_data_01.parquet'

# Read the Parquet file
table = pq.read_table(parquet_file_path)

df = table.to_pandas()

df
# Out:
#     unique_id                                      pos  \
# 0           1   [14.925555271304676, 50.4798223362775]
# 1           2    [80.0427146553251, 74.57782532053287]
# 2           3   [69.53571932797675, 39.94511156373348]
# 3           4   [75.00850924813618, 53.54429411651976]
# 4           5  [3.889236104430667, 48.418594404023835]
# ..        ...                                      ...
# 95         96   [6.464763253135144, 52.72900810101853]
# 96         97   [95.92048608056925, 9.095230875228715]
# 97         98   [70.91409243852897, 58.82551284546496]
# 98         99  [14.043567318048304, 99.00223373298071]
# 99        100  [71.14598887924967, 33.626164822977856]
#
#                                      direction  vision  speed
# 0    [0.07172595217832861, 0.9974243769750727]       5      5
# 1     [0.5928668178845761, 0.8053005254260157]       5      5
# 2   [-0.7320355950697671, -0.6812663851613786]       5      5
# 3   [-0.9987072930413169, 0.05083053045252489]       5      5
# 4     [-0.8252269626839055, 0.564801257133424]       5      5
# ..                                         ...     ...    ...
# 95  [-0.6164372259515534, -0.7874040554004997]       5      5
# 96  [-0.1388607983434644, -0.9903119097958056]       5      5
# 97   [-0.9967097419274553, 0.0810536263649288]       5      5
# 98   [-0.5953332713603802, 0.8034788709178035]       5      5
# 99  [-0.5048343135163399, -0.8632162625301297]       5      5
#
# [100 rows x 5 columns]

# %% [markdown]
# # Reconstructing the agent

# %%
from mesa.visualization.utils import force_update


import solara

update_counter = solara.reactive(0)


def force_update():  # noqa: D103
    update_counter.value += 1
    
class CustomBoidFlockers(BoidFlockers):
    
    def step(self):
        #self.steps += 1
        padding = len(str(100)) - 1

        parquet_file_path = f'output_dir/grid_data_{self.steps:0{padding}}.parquet'
        table = pq.read_table(parquet_file_path)

        
        df = table.to_pandas()

        column_list = df.columns
       
        self._agents.clear()

        for idx, row in df.iterrows():
            agent = Boid(reconstructed_model, None, None, None, None)
            
            for column in column_list:
                setattr(agent, column, row[column])
        force_update()
        # original_step()
        # update_counter.set(update_counter.value + 1)

CustomBoidFlockers()

# %%
# update_counter = solara.reactive(0)
# reconstructed_model = solara.reactive(None)  # Initialize the reactive model variable here

reconstructed_model = CustomBoidFlockers()

column_list = df.columns
agent_list = []
for idx, row in df.iterrows():
    agent = Boid(reconstructed_model, None, None, None, None)
    for column in column_list:
        setattr(agent, column, row[column])
    agent_list.append(agent)
agent_list
# Out:
# [<__main__.Boid at 0x7f3d4c0fcc10>,
#  <__main__.Boid at 0x7f3d4c0fcbe0>,
#  <__main__.Boid at 0x7f3d4c0fcd90>,
#  <__main__.Boid at 0x7f3d4c0fcc70>,
#  <__main__.Boid at 0x7f3d4c0fcdc0>,
#  <__main__.Boid at 0x7f3d4c0fcca0>,
#  <__main__.Boid at 0x7f3d4c0fcdf0>,
#  <__main__.Boid at 0x7f3d4c0fcc40>,
#  <__main__.Boid at 0x7f3d4c0fcd30>,
#  <__main__.Boid at 0x7f3d4c0fccd0>,
#  <__main__.Boid at 0x7f3d4c0fce20>,
#  <__main__.Boid at 0x7f3d4c0fcd60>,
#  <__main__.Boid at 0x7f3d4c0fcd00>,
#  <__main__.Boid at 0x7f3d4c0fce50>,
#  <__main__.Boid at 0x7f3d4c0fce80>,
#  <__main__.Boid at 0x7f3d4c0fceb0>,
#  <__main__.Boid at 0x7f3d4c0fcee0>,
#  <__main__.Boid at 0x7f3d4c0fcf10>,
#  <__main__.Boid at 0x7f3d4c0fcf40>,
#  <__main__.Boid at 0x7f3d4c0fcf70>,
#  <__main__.Boid at 0x7f3d4c0fcfa0>,
#  <__main__.Boid at 0x7f3d4c0fcfd0>,
#  <__main__.Boid at 0x7f3d4c0fd000>,
#  <__main__.Boid at 0x7f3d4c0fd030>,
#  <__main__.Boid at 0x7f3d4c0fd060>,
#  <__main__.Boid at 0x7f3d4c0fd090>,
#  <__main__.Boid at 0x7f3d4c0fd0c0>,
#  <__main__.Boid at 0x7f3d4c0fd0f0>,
#  <__main__.Boid at 0x7f3d4c0fd120>,
#  <__main__.Boid at 0x7f3d4c0fd150>,
#  <__main__.Boid at 0x7f3d4c0fd180>,
#  <__main__.Boid at 0x7f3d4c0fd1b0>,
#  <__main__.Boid at 0x7f3d4c0fd1e0>,
#  <__main__.Boid at 0x7f3d4c0fd210>,
#  <__main__.Boid at 0x7f3d4c0fd240>,
#  <__main__.Boid at 0x7f3d4c0fd270>,
#  <__main__.Boid at 0x7f3d4c0fd2a0>,
#  <__main__.Boid at 0x7f3d4c0fd2d0>,
#  <__main__.Boid at 0x7f3d4c0fd300>,
#  <__main__.Boid at 0x7f3d4c0fd330>,
#  <__main__.Boid at 0x7f3d4c0fd360>,
#  <__main__.Boid at 0x7f3d4c0fd390>,
#  <__main__.Boid at 0x7f3d4c0fd3c0>,
#  <__main__.Boid at 0x7f3d4c0fd3f0>,
#  <__main__.Boid at 0x7f3d4c0fd420>,
#  <__main__.Boid at 0x7f3d4c0fd450>,
#  <__main__.Boid at 0x7f3d4c0fd480>,
#  <__main__.Boid at 0x7f3d4c0fd4b0>,
#  <__main__.Boid at 0x7f3d4c0fd4e0>,
#  <__main__.Boid at 0x7f3d4c0fd510>,
#  <__main__.Boid at 0x7f3d4c0fd540>,
#  <__main__.Boid at 0x7f3d4c0fd570>,
#  <__main__.Boid at 0x7f3d4c0fd5a0>,
#  <__main__.Boid at 0x7f3d4c0fd5d0>,
#  <__main__.Boid at 0x7f3d4c0fd600>,
#  <__main__.Boid at 0x7f3d4c0fd630>,
#  <__main__.Boid at 0x7f3d4c0fd660>,
#  <__main__.Boid at 0x7f3d4c0fd690>,
#  <__main__.Boid at 0x7f3d4c0fd6c0>,
#  <__main__.Boid at 0x7f3d4c0fd6f0>,
#  <__main__.Boid at 0x7f3d4c0fd720>,
#  <__main__.Boid at 0x7f3d4c0fd750>,
#  <__main__.Boid at 0x7f3d4c0fd780>,
#  <__main__.Boid at 0x7f3d4c0fd7b0>,
#  <__main__.Boid at 0x7f3d4c0fd7e0>,
#  <__main__.Boid at 0x7f3d4c0fd810>,
#  <__main__.Boid at 0x7f3d4c0fd840>,
#  <__main__.Boid at 0x7f3d4c0fd870>,
#  <__main__.Boid at 0x7f3d4c0fd8a0>,
#  <__main__.Boid at 0x7f3d4c0fd8d0>,
#  <__main__.Boid at 0x7f3d4c0fd900>,
#  <__main__.Boid at 0x7f3d4c0fd930>,
#  <__main__.Boid at 0x7f3d4c0fd960>,
#  <__main__.Boid at 0x7f3d4c0fd990>,
#  <__main__.Boid at 0x7f3d4c0fd9c0>,
#  <__main__.Boid at 0x7f3d4c0fd9f0>,
#  <__main__.Boid at 0x7f3d4c0fda20>,
#  <__main__.Boid at 0x7f3d4c0fda50>,
#  <__main__.Boid at 0x7f3d4c0fda80>,
#  <__main__.Boid at 0x7f3d4c0fdab0>,
#  <__main__.Boid at 0x7f3d4c0fdae0>,
#  <__main__.Boid at 0x7f3d4c0fdb10>,
#  <__main__.Boid at 0x7f3d4c0fdb40>,
#  <__main__.Boid at 0x7f3d4c0fdb70>,
#  <__main__.Boid at 0x7f3d4c0fdba0>,
#  <__main__.Boid at 0x7f3d4c0fdbd0>,
#  <__main__.Boid at 0x7f3d4c0fdc00>,
#  <__main__.Boid at 0x7f3d4c0fdc30>,
#  <__main__.Boid at 0x7f3d4c0fdc60>,
#  <__main__.Boid at 0x7f3d4c0fdc90>,
#  <__main__.Boid at 0x7f3d4c0fdcc0>,
#  <__main__.Boid at 0x7f3d4c0fdcf0>,
#  <__main__.Boid at 0x7f3d4c8cbca0>,
#  <__main__.Boid at 0x7f3d4c64cd30>,
#  <__main__.Boid at 0x7f3d4c64fb20>,
#  <__main__.Boid at 0x7f3d4c0fdd80>,
#  <__main__.Boid at 0x7f3d4c64f070>,
#  <__main__.Boid at 0x7f3d4c0fddb0>,
#  <__main__.Boid at 0x7f3d4c0fdd20>,
#  <__main__.Boid at 0x7f3d4c0fde10>]

# %%
# test plotting

import matplotlib.pyplot as plt
def draw_boids(model):
    x_vals = []
    y_vals = []
    for boid in model.agents:
        x, y = boid.pos
        x_vals.append(x)
        y_vals.append(y)
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111)
    ax.scatter(x_vals, y_vals)
draw_boids(reconstructed_model)

# %%
from mesa.visualization import SolaraViz, make_space_matplotlib
# update_counter = solara.reactive(0)
def boid_draw(agent):
    return {"color": "tab:red"}
model_params = {
    "population": 100,
    "width": 100,
    "height": 100,
    "speed": 5,
    "vision": 10,
    "separation": 2,
}


# page = SolaraViz(
#     reconstructed_model,
#     [make_space_matplotlib(agent_portrayal=boid_draw)],
#     model_params=model_params,
#     name="Boid Flocking Model",
#     update_counter=update_counter
# )

@solara.component
def BoidFlockersViz():
    update_counter.get()  # This makes SolaraViz reactive to updates

    page = SolaraViz(
        reconstructed_model,
        [make_space_matplotlib(agent_portrayal=boid_draw)],
        model_params=model_params,
        name="Boid Flocking Model"
    )
    return page

BoidFlockersViz() 

#page  # noqa
# Out:
# Cannot show ipywidgets in text

# %% [markdown]
# # Manually printing grids with for loops

# %%
for i in range(1,100):
    reconstructed_model = CustomBoidFlockers()
    parquet_file_path = f'output_dir/grid_data_{i:0{2}}.parquet'
    print(parquet_file_path)
    
    # Read the Parquet file
    table = pq.read_table(parquet_file_path)
    
    # Convert the table to a pandas DataFrame 
    df = table.to_pandas()
    
    column_list = df.columns
    
    agent_list = []
    for idx, row in df.iterrows():
        agent = Boid(reconstructed_model, None, None, None, None)
        for column in column_list:
            setattr(agent, column, row[column])
        # agent_list.append(agent)
    draw_boids(reconstructed_model)
# Out:
# output_dir/grid_data_01.parquet
# output_dir/grid_data_02.parquet
# output_dir/grid_data_03.parquet
# output_dir/grid_data_04.parquet
# output_dir/grid_data_05.parquet
# output_dir/grid_data_06.parquet
# output_dir/grid_data_07.parquet
# output_dir/grid_data_08.parquet
# output_dir/grid_data_09.parquet
# output_dir/grid_data_10.parquet
# output_dir/grid_data_11.parquet
# output_dir/grid_data_12.parquet
# output_dir/grid_data_13.parquet
# output_dir/grid_data_14.parquet
# output_dir/grid_data_15.parquet
# output_dir/grid_data_16.parquet
# output_dir/grid_data_17.parquet
# output_dir/grid_data_18.parquet
# output_dir/grid_data_19.parquet
# output_dir/grid_data_20.parquet
# output_dir/grid_data_21.parquet
# /tmp/ipykernel_47953/3554360005.py:11: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figsize=(10, 10))
# output_dir/grid_data_22.parquet
# output_dir/grid_data_23.parquet
# output_dir/grid_data_24.parquet
# output_dir/grid_data_25.parquet
# output_dir/grid_data_26.parquet
# output_dir/grid_data_27.parquet
# output_dir/grid_data_28.parquet
# output_dir/grid_data_29.parquet
# output_dir/grid_data_30.parquet
# output_dir/grid_data_31.parquet
# output_dir/grid_data_32.parquet
# output_dir/grid_data_33.parquet
# output_dir/grid_data_34.parquet
# output_dir/grid_data_35.parquet
# output_dir/grid_data_36.parquet
# output_dir/grid_data_37.parquet
# output_dir/grid_data_38.parquet
# output_dir/grid_data_39.parquet
# output_dir/grid_data_40.parquet
# output_dir/grid_data_41.parquet
# output_dir/grid_data_42.parquet
# output_dir/grid_data_43.parquet
# output_dir/grid_data_44.parquet
# output_dir/grid_data_45.parquet
# output_dir/grid_data_46.parquet
# output_dir/grid_data_47.parquet
# output_dir/grid_data_48.parquet
# output_dir/grid_data_49.parquet
# output_dir/grid_data_50.parquet
# output_dir/grid_data_51.parquet
# output_dir/grid_data_52.parquet
# output_dir/grid_data_53.parquet
# output_dir/grid_data_54.parquet
# output_dir/grid_data_55.parquet
# output_dir/grid_data_56.parquet
# output_dir/grid_data_57.parquet
# output_dir/grid_data_58.parquet
# output_dir/grid_data_59.parquet
# output_dir/grid_data_60.parquet
# output_dir/grid_data_61.parquet
# output_dir/grid_data_62.parquet
# output_dir/grid_data_63.parquet
# output_dir/grid_data_64.parquet
# output_dir/grid_data_65.parquet
# output_dir/grid_data_66.parquet
# output_dir/grid_data_67.parquet
# output_dir/grid_data_68.parquet
# output_dir/grid_data_69.parquet
# output_dir/grid_data_70.parquet
# output_dir/grid_data_71.parquet
# output_dir/grid_data_72.parquet
# output_dir/grid_data_73.parquet
# output_dir/grid_data_74.parquet
# output_dir/grid_data_75.parquet
# output_dir/grid_data_76.parquet
# output_dir/grid_data_77.parquet
# output_dir/grid_data_78.parquet
# output_dir/grid_data_79.parquet
# output_dir/grid_data_80.parquet
# output_dir/grid_data_81.parquet
# output_dir/grid_data_82.parquet
# output_dir/grid_data_83.parquet
# output_dir/grid_data_84.parquet
# output_dir/grid_data_85.parquet
# output_dir/grid_data_86.parquet
# output_dir/grid_data_87.parquet
# output_dir/grid_data_88.parquet
# output_dir/grid_data_89.parquet
# output_dir/grid_data_90.parquet
# output_dir/grid_data_91.parquet
# output_dir/grid_data_92.parquet
# output_dir/grid_data_93.parquet
# output_dir/grid_data_94.parquet
# output_dir/grid_data_95.parquet
# output_dir/grid_data_96.parquet
# output_dir/grid_data_97.parquet
# output_dir/grid_data_98.parquet
# output_dir/grid_data_99.parquet
