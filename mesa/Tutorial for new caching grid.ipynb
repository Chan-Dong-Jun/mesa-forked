# %% [markdown]
# # Model hidden

# %%
"""
Flockers
=============================================================
A Mesa implementation of Craig Reynolds's Boids flocker model.
Uses numpy arrays to represent vectors.
"""

import mesa
import numpy as np


class Boid(mesa.Agent):
    """
    A Boid-style flocker agent.

    The agent follows three behaviors to flock:
        - Cohesion: steering towards neighboring agents.
        - Separation: avoiding getting too close to any other agent.
        - Alignment: try to fly in the same direction as the neighbors.

    Boids have a vision that defines the radius in which they look for their
    neighbors to flock with. Their speed (a scalar) and direction (a vector)
    define their movement. Separation is their desired minimum distance from
    any other Boid.
    """

    def __init__(
        self,
        unique_id,
        model,
        speed,
        direction,
        vision,
        separation,
        cohere=0.03,
        separate=0.015,
        match=0.05,
    ):
        """
        Create a new Boid flocker agent.

        Args:
            speed: Distance to move per step.
            direction: numpy vector for the Boid's direction of movement.
            vision: Radius to look around for nearby Boids.
            separation: Minimum distance to maintain from other Boids.
            cohere: the relative importance of matching neighbors' positions
            separate: the relative importance of avoiding close neighbors
            match: the relative importance of matching neighbors' headings
        """
        super().__init__(unique_id, model)
        self.speed = speed
        self.direction = direction
        self.vision = vision
        self.separation = separation
        self.cohere_factor = cohere
        self.separate_factor = separate
        self.match_factor = match
        self.neighbors = None

    def step(self):
        """
        Get the Boid's neighbors, compute the new vector, and move accordingly.
        """

        self.neighbors = self.model.space.get_neighbors(self.pos, self.vision, False)
        n = 0
        match_vector, separation_vector, cohere = np.zeros((3, 2))
        for neighbor in self.neighbors:
            n += 1
            heading = self.model.space.get_heading(self.pos, neighbor.pos)
            cohere += heading
            if self.model.space.get_distance(self.pos, neighbor.pos) < self.separation:
                separation_vector -= heading
            match_vector += neighbor.direction
        n = max(n, 1)
        cohere = cohere * self.cohere_factor
        separation_vector = separation_vector * self.separate_factor
        match_vector = match_vector * self.match_factor
        self.direction += (cohere + separation_vector + match_vector) / n
        self.direction /= np.linalg.norm(self.direction)
        new_pos = self.pos + self.direction * self.speed
        self.model.space.move_agent(self, new_pos)


class BoidFlockers(mesa.Model):
    """
    Flocker model class. Handles agent creation, placement and scheduling.
    """

    def __init__(
        self,
        seed=None,
        population=100,
        width=100,
        height=100,
        vision=10,
        speed=1,
        separation=1,
        cohere=0.03,
        separate=0.015,
        match=0.05,
    ):
        """
        Create a new Flockers model.

        Args:
            population: Number of Boids
            width, height: Size of the space.
            speed: How fast should the Boids move.
            vision: How far around should each Boid look for its neighbors
            separation: What's the minimum distance each Boid will attempt to
                    keep from any other
            cohere, separate, match: factors for the relative importance of
                    the three drives.
        """
        super().__init__(seed=seed)
        self.population = population
        self.vision = vision
        self.speed = speed
        self.separation = separation

        self.space = mesa.space.ContinuousSpace(width, height, True)
        self.factors = {"cohere": cohere, "separate": separate, "match": match}
        self.make_agents()

    def make_agents(self):
        """
        Create self.population agents, with random positions and starting headings.
        """
        for i in range(self.population):
            x = self.random.random() * self.space.x_max
            y = self.random.random() * self.space.y_max
            pos = np.array((x, y))
            direction = np.random.random(2) * 2 - 1
            boid = Boid(
                unique_id=i,
                model=self,
                speed=self.speed,
                direction=direction,
                vision=self.vision,
                separation=self.separation,
                **self.factors,
            )
            self.space.place_agent(boid, pos)

    def step(self):
        self.agents.shuffle().do("step")

# %% [markdown]
# # SugarScape model

# %%
class SugarscapeCg(mesa.Model):
    """
    Sugarscape 2 Constant Growback
    """

    verbose = True  # Print-monitoring

    def __init__(self, width=50, height=50, initial_population=100):
        """
        Create a new Constant Growback model with the given parameters.

        Args:
            initial_population: Number of population to start with
        """
        super().__init__()

        # Set parameters
        self.width = width
        self.height = height
        self.initial_population = initial_population

        self.grid = mesa.space.MultiGrid(self.width, self.height, torus=False)
        self.datacollector = mesa.DataCollector(
            {"SsAgent": lambda m: len(m.agents_by_type[SsAgent])}
        )

        # Create sugar
        import numpy as np

        sugar_distribution = np.genfromtxt("sugar-map.txt")
        for _, (x, y) in self.grid.coord_iter():
            max_sugar = sugar_distribution[x, y]
            sugar = Sugar(self, max_sugar)
            self.grid.place_agent(sugar, (x, y))

        # Create agent:
        for i in range(self.initial_population):
            x = self.random.randrange(self.width)
            y = self.random.randrange(self.height)
            sugar = self.random.randrange(6, 25)
            metabolism = self.random.randrange(2, 4)
            vision = self.random.randrange(1, 6)
            ssa = SsAgent(self, False, sugar, metabolism, vision)
            self.grid.place_agent(ssa, (x, y))

        self.running = True
        self.datacollector.collect(self)

    def step(self):
        # Step suger and agents
        self.agents_by_type[Sugar].do("step")
        self.agents_by_type[SsAgent].shuffle_do("step")
        # collect data
        self.datacollector.collect(self)
        if self.verbose:
            print(f"Step: {self.steps}, SsAgents: {len(self.agents_by_type[SsAgent])}")

    def run_model(self, step_count=200):
        if self.verbose:
            print(
                f"Initial number Sugarscape Agents: {len(self.agents_by_type[SsAgent])}"
            )

        for i in range(step_count):
            self.step()

        if self.verbose:
            print(
                f"\nFinal number Sugarscape Agents: {len(self.agents_by_type[SsAgent])}"
            )

# %%
def get_distance(pos_1, pos_2):
    """Get the distance between two point

    Args:
        pos_1, pos_2: Coordinate tuples for both points.
    """
    x1, y1 = pos_1
    x2, y2 = pos_2
    dx = x1 - x2
    dy = y1 - y2
    return math.sqrt(dx**2 + dy**2)


class SsAgent(mesa.Agent):
    def __init__(self, model, moore=False, sugar=0, metabolism=0, vision=0):
        super().__init__(model)
        self.moore = moore
        self.sugar = sugar
        self.metabolism = metabolism
        self.vision = vision

    def get_sugar(self, pos):
        this_cell = self.model.grid.get_cell_list_contents([pos])
        for agent in this_cell:
            if type(agent) is Sugar:
                return agent

    def is_occupied(self, pos):
        this_cell = self.model.grid.get_cell_list_contents([pos])
        return any(isinstance(agent, SsAgent) for agent in this_cell)

    def move(self):
        # Get neighborhood within vision
        neighbors = [
            i
            for i in self.model.grid.get_neighborhood(
                self.pos, self.moore, False, radius=self.vision
            )
            if not self.is_occupied(i)
        ]
        neighbors.append(self.pos)
        # Look for location with the most sugar
        max_sugar = max(self.get_sugar(pos).amount for pos in neighbors)
        candidates = [
            pos for pos in neighbors if self.get_sugar(pos).amount == max_sugar
        ]
        # Narrow down to the nearest ones
        min_dist = min(get_distance(self.pos, pos) for pos in candidates)
        final_candidates = [
            pos for pos in candidates if get_distance(self.pos, pos) == min_dist
        ]
        self.random.shuffle(final_candidates)
        self.model.grid.move_agent(self, final_candidates[0])

    def eat(self):
        sugar_patch = self.get_sugar(self.pos)
        self.sugar = self.sugar - self.metabolism + sugar_patch.amount
        sugar_patch.amount = 0

    def step(self):
        self.move()
        self.eat()
        if self.sugar <= 0:
            self.model.grid.remove_agent(self)
            self.remove()


class Sugar(mesa.Agent):
    def __init__(self, model, max_sugar):
        super().__init__(model)
        self.amount = max_sugar
        self.max_sugar = max_sugar

    def step(self):
        self.amount = min([self.max_sugar, self.amount + 1])

# %% [markdown]
# # test sugar scape

# %%
from pathlib import Path

# %%
model = SugarscapeCg(width=50, height=50, initial_population=100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model = SugarscapeCg(width=50, height=50, initial_population=100)
#
# Cell In[2], line 33, in SugarscapeCg.__init__(self, width, height, initial_population)
#      31 for _, (x, y) in self.grid.coord_iter():
#      32     max_sugar = sugar_distribution[x, y]
# ---> 33     sugar = Sugar(self, max_sugar)
#      34     self.grid.place_agent(sugar, (x, y))
#      36 # Create agent:
#
# Cell In[3], line 70, in Sugar.__init__(self, model, max_sugar)
#      69 def __init__(self, model, max_sugar):
# ---> 70     super().__init__(model)
#      71     self.amount = max_sugar
#      72     self.max_sugar = max_sugar
#
# TypeError: Agent.__init__() missing 1 required positional argument: 'model'

# %% [markdown]
# # Testing

# %%
model = BoidFlockers(100, 100, 100, speed=5, vision=5, separation=1)

# %%
from mesa.cacheable_model import CacheableModel
parameters = ['unique_id', 'pos', 'direction', 'vision', 'speed']
cacheable_model = CacheableModel(model, "output_dir", 100, 100, condition_function=None)
for i in range(100):
    cacheable_model.model.step()
    cacheable_model.get_data(parameters)
# Out:
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet
# 0
# output_dir/grid_data_00.parquet

# %%
import pyarrow.parquet as pq

# Specify the path to your Parquet file
parquet_file_path = 'output_dir/grid_data_00.parquet'

# Read the Parquet file
table = pq.read_table(parquet_file_path)

# Convert the table to a pandas DataFrame 
df = table.to_pandas()

# Display the DataFrame
df
# Out:
#     unique_id                                      pos  \
# 0           0  [35.16097010240313, 19.999474315871907]
# 1           1  [38.79573096923578, 62.090884941004916]
# 2           2   [61.80900256297662, 39.85568409709933]
# 3           3   [80.81284510937842, 91.15839853728859]
# 4           4  [10.232938049159117, 41.86371728245083]
# ..        ...                                      ...
# 95         95   [34.26374998874098, 57.72817674806151]
# 96         96  [69.42021067172772, 58.240745328099905]
# 97         97   [69.89356058116424, 5.911341498177485]
# 98         98   [88.72109018952585, 16.14148214819678]
# 99         99   [45.82839099320903, 9.424407803057301]
#
#                                      direction  vision  speed
# 0   [-0.7473243931438508, -0.6644593677661375]       5      5
# 1    [0.5488249488082567, -0.8359373036093164]       5      5
# 2    [0.8238606748642199, -0.5667923679904945]       5      5
# 3    [-0.8183123919426883, -0.574773719991647]       5      5
# 4   [0.9403802236406391, -0.34012502846097875]       5      5
# ..                                         ...     ...    ...
# 95   [-0.7615181045246203, 0.6481436387724788]       5      5
# 96  [-0.8571043819751183, -0.5151427747712769]       5      5
# 97    [0.06338689983849959, 0.997989028461167]       5      5
# 98  [-0.1807110265957716, -0.9835362346485779]       5      5
# 99  [-0.9489036733387767, 0.31556587065805447]       5      5
#
# [100 rows x 5 columns]

# %%
# reconstructing the agent

# %%
column_list = df.columns

for idx, row in df.iterrows():
    for column in column_list:
        print(row[column])
# Out:
# 0
# [35.1609701  19.99947432]
# [-0.74732439 -0.66445937]
# 5
# 5
# 1
# [38.79573097 62.09088494]
# [ 0.54882495 -0.8359373 ]
# 5
# 5
# 2
# [61.80900256 39.8556841 ]
# [ 0.82386067 -0.56679237]
# 5
# 5
# 3
# [80.81284511 91.15839854]
# [-0.81831239 -0.57477372]
# 5
# 5
# 4
# [10.23293805 41.86371728]
# [ 0.94038022 -0.34012503]
# 5
# 5
# 5
# [13.96351077  4.21115639]
# [0.07241175 0.99737482]
# 5
# 5
# 6
# [79.83145771 12.5216323 ]
# [-0.34469276 -0.93871556]
# 5
# 5
# 7
# [47.89253115  7.10641491]
# [-0.67980145 -0.73339621]
# 5
# 5
# 8
# [61.38948976 66.57486984]
# [-0.6971417   0.71693336]
# 5
# 5
# 9
# [93.13133623 16.58976691]
# [ 0.87415445 -0.48564802]
# 5
# 5
# 10
# [67.59005771 25.87480249]
# [ 0.35055812 -0.93654098]
# 5
# 5
# 11
# [28.51316701 25.89078985]
# [-0.70350044 -0.71069483]
# 5
# 5
# 12
# [27.22610483 83.38860442]
# [0.6490938  0.76070838]
# 5
# 5
# 13
# [65.05117909 76.22130824]
# [ 0.49807534 -0.86713376]
# 5
# 5
# 14
# [22.86589289 76.03178069]
# [-0.99268126 -0.12076387]
# 5
# 5
# 15
# [17.31652309  2.6388061 ]
# [0.13822015 0.99040153]
# 5
# 5
# 16
# [39.48337682 94.27979254]
# [-0.00999137  0.99995008]
# 5
# 5
# 17
# [95.15694546 14.82538268]
# [-0.74505203 -0.66700635]
# 5
# 5
# 18
# [28.46092965 26.96284351]
# [-0.80468813 -0.59369774]
# 5
# 5
# 19
# [93.48209449 76.39678955]
# [-0.93850823  0.34525688]
# 5
# 5
# 20
# [24.58193573 76.04107673]
# [-0.99793915 -0.06416735]
# 5
# 5
# 21
# [87.52013281 91.85434492]
# [-0.99956497  0.02949359]
# 5
# 5
# 22
# [29.12063382 18.08774868]
# [-0.88447126  0.46659468]
# 5
# 5
# 23
# [83.00355344 36.67582315]
# [-0.02613262  0.99965848]
# 5
# 5
# 24
# [35.10220322 92.03992916]
# [-0.01971389  0.99980566]
# 5
# 5
# 25
# [57.57540662 37.6495779 ]
# [-0.99132028  0.13146901]
# 5
# 5
# 26
# [58.79391003 61.49800077]
# [-0.84434401  0.53580144]
# 5
# 5
# 27
# [59.69088605 40.16646716]
# [-0.96921419 -0.24621911]
# 5
# 5
# 28
# [25.01055764 77.92448333]
# [-0.99819608  0.06003823]
# 5
# 5
# 29
# [23.99624323 38.08666596]
# [-0.395296    0.91855379]
# 5
# 5
# 30
# [44.27525741  9.63684762]
# [0.4997171  0.86618868]
# 5
# 5
# 31
# [37.579372   83.45582285]
# [0.90003062 0.43582667]
# 5
# 5
# 32
# [24.12399169 75.95162273]
# [-0.98611112 -0.1660869 ]
# 5
# 5
# 33
# [25.39167095 77.68571917]
# [-0.98329191 -0.18203579]
# 5
# 5
# 34
# [96.31712097 76.67942839]
# [-0.62557532 -0.78016378]
# 5
# 5
# 35
# [25.16274595 75.01015499]
# [-0.99934758 -0.03611666]
# 5
# 5
# 36
# [45.13659816 31.85735749]
# [-0.88229971 -0.47068803]
# 5
# 5
# 37
# [16.94245284 12.26603394]
# [0.58023177 0.81445141]
# 5
# 5
# 38
# [58.93460517 41.09280281]
# [ 0.92864407 -0.37097196]
# 5
# 5
# 39
# [27.46517153 56.04585598]
# [-0.80018858 -0.59974848]
# 5
# 5
# 40
# [55.2060239  72.06186786]
# [-0.6230696 -0.7821664]
# 5
# 5
# 41
# [74.21982378 32.94495778]
# [0.83568778 0.54920482]
# 5
# 5
# 42
# [81.07461876 24.04666534]
# [-0.68741107  0.72626856]
# 5
# 5
# 43
# [55.35395464 17.200958  ]
# [-0.83413199  0.55156489]
# 5
# 5
# 44
# [42.86149558 82.40347453]
# [-0.99993164  0.01169225]
# 5
# 5
# 45
# [15.28432435  5.95763078]
# [0.09238537 0.99572333]
# 5
# 5
# 46
# [11.91535601 53.4404523 ]
# [ 0.38415341 -0.92326928]
# 5
# 5
# 47
# [59.56389122 94.67810681]
# [-0.99221797  0.12451305]
# 5
# 5
# 48
# [63.6635687  78.00094236]
# [ 0.51775828 -0.85552695]
# 5
# 5
# 49
# [44.94206028 81.38440389]
# [-0.63722268 -0.77067974]
# 5
# 5
# 50
# [24.84687006 45.90703089]
# [ 0.16055453 -0.98702697]
# 5
# 5
# 51
# [87.74613291 74.58766334]
# [-0.55051215  0.83482715]
# 5
# 5
# 52
# [72.37031042 68.48451865]
# [0.62230005 0.78277879]
# 5
# 5
# 53
# [76.99474409 21.81912139]
# [-0.75314019  0.65786005]
# 5
# 5
# 54
# [88.04861533 83.3804535 ]
# [ 0.76458888 -0.64451831]
# 5
# 5
# 55
# [83.06294803 35.53998819]
# [-0.99644998  0.08418692]
# 5
# 5
# 56
# [42.8969554   6.78186645]
# [0.12504044 0.99215165]
# 5
# 5
# 57
# [9.25734676 0.93924089]
# [-0.62484098  0.78075205]
# 5
# 5
# 58
# [36.45978162 76.29824271]
# [-0.70262556  0.71155978]
# 5
# 5
# 59
# [33.56542846 18.74550267]
# [ 0.97119608 -0.2382817 ]
# 5
# 5
# 60
# [11.19528174 40.19793311]
# [0.63634259 0.77140658]
# 5
# 5
# 61
# [69.68174628 38.00085046]
# [-0.16397933 -0.98646378]
# 5
# 5
# 62
# [80.58696641 16.3704913 ]
# [-0.29821006 -0.95450027]
# 5
# 5
# 63
# [81.67770091 50.77280193]
# [-0.37503792 -0.92700947]
# 5
# 5
# 64
# [37.27147877 85.42676511]
# [0.80139802 0.59813144]
# 5
# 5
# 65
# [35.95405073 79.06188098]
# [-0.66437858  0.74739621]
# 5
# 5
# 66
# [27.69585633 34.40150757]
# [-0.99693328  0.07825618]
# 5
# 5
# 67
# [41.54760673 95.88704029]
# [-0.99074271  0.13575305]
# 5
# 5
# 68
# [50.13060929 11.25540778]
# [0.08516196 0.99636712]
# 5
# 5
# 69
# [91.36418426 76.08478256]
# [-0.47859485 -0.87803586]
# 5
# 5
# 70
# [26.02756555 57.30225721]
# [-0.66488899 -0.74694219]
# 5
# 5
# 71
# [38.65465991 29.53715533]
# [-0.26802551 -0.96341182]
# 5
# 5
# 72
# [14.73157333 89.19550692]
# [-0.83665992  0.54772273]
# 5
# 5
# 73
# [67.22960582  3.87090602]
# [-0.36881311 -0.92950357]
# 5
# 5
# 74
# [87.12738521 49.37846787]
# [0.51754818 0.85565407]
# 5
# 5
# 75
# [28.24384729 21.00993454]
# [-0.76156104 -0.64809319]
# 5
# 5
# 76
# [72.46705438 31.74176488]
# [ 0.91897081 -0.39432556]
# 5
# 5
# 77
# [27.51142004 83.69258527]
# [0.59902415 0.80073096]
# 5
# 5
# 78
# [2.41036825 9.21963671]
# [ 0.5944635  -0.80412259]
# 5
# 5
# 79
# [33.07390433 84.66920249]
# [-0.84507478  0.53464813]
# 5
# 5
# 80
# [41.88524461 79.55554788]
# [-0.9968037   0.07988977]
# 5
# 5
# 81
# [98.09142822 15.14514232]
# [-0.85913318  0.51175207]
# 5
# 5
# 82
# [ 0.98761067 73.34925648]
# [-0.53152256 -0.84704413]
# 5
# 5
# 83
# [27.01872604 32.7313686 ]
# [-0.95803196 -0.2866614 ]
# 5
# 5
# 84
# [92.34076793 84.71674254]
# [-0.05554702 -0.99845607]
# 5
# 5
# 85
# [66.88143933 22.21812318]
# [-0.92037617  0.39103414]
# 5
# 5
# 86
# [79.80064221 14.12269263]
# [-0.35868647 -0.9334581 ]
# 5
# 5
# 87
# [ 4.23060229 35.48700438]
# [-0.99831297 -0.05806219]
# 5
# 5
# 88
# [94.8566928  5.7980382]
# [-0.99996021 -0.00892025]
# 5
# 5
# 89
# [76.3459425  14.02761529]
# [-0.17691013  0.98422701]
# 5
# 5
# 90
# [21.3355109  58.96276711]
# [-0.81803805  0.57516411]
# 5
# 5
# 91
# [99.77399564 24.30465885]
# [-0.26344515 -0.96467438]
# 5
# 5
# 92
# [5.53776577 0.23791001]
# [-0.79909383  0.60120632]
# 5
# 5
# 93
# [95.88453391 13.13052379]
# [-0.49025404  0.87157958]
# 5
# 5
# 94
# [23.46153185 84.75351512]
# [-0.9940728  -0.10871648]
# 5
# 5
# 95
# [34.26374999 57.72817675]
# [-0.7615181   0.64814364]
# 5
# 5
# 96
# [69.42021067 58.24074533]
# [-0.85710438 -0.51514277]
# 5
# 5
# 97
# [69.89356058  5.9113415 ]
# [0.0633869  0.99798903]
# 5
# 5
# 98
# [88.72109019 16.14148215]
# [-0.18071103 -0.98353623]
# 5
# 5
# 99
# [45.82839099  9.4244078 ]
# [-0.94890367  0.31556587]
# 5
# 5

# %%
mesa.Model().agents_
model.agents_
# Out:
# defaultdict(dict,
#             {__main__.Boid: {<__main__.Boid at 0x7fca50d55810>: None,
#               <__main__.Boid at 0x7fca50d55600>: None,
#               <__main__.Boid at 0x7fca50d566e0>: None,
#               <__main__.Boid at 0x7fca50d55a50>: None,
#               <__main__.Boid at 0x7fca50d57070>: None,
#               <__main__.Boid at 0x7fca50d56500>: None,
#               <__main__.Boid at 0x7fca50d55c90>: None,
#               <__main__.Boid at 0x7fca50d562c0>: None,
#               <__main__.Boid at 0x7fca50d56620>: None,
#               <__main__.Boid at 0x7fca50d56470>: None,
#               <__main__.Boid at 0x7fca50d55b40>: None,
#               <__main__.Boid at 0x7fca50d55ae0>: None,
#               <__main__.Boid at 0x7fca50d55ab0>: None,
#               <__main__.Boid at 0x7fca50d560b0>: None,
#               <__main__.Boid at 0x7fca50d56260>: None,
#               <__main__.Boid at 0x7fca50d55630>: None,
#               <__main__.Boid at 0x7fca50d56710>: None,
#               <__main__.Boid at 0x7fca50d55840>: None,
#               <__main__.Boid at 0x7fca50d55690>: None,
#               <__main__.Boid at 0x7fca50d55780>: None,
#               <__main__.Boid at 0x7fca50d555a0>: None,
#               <__main__.Boid at 0x7fca50d55b70>: None,
#               <__main__.Boid at 0x7fca50d557b0>: None,
#               <__main__.Boid at 0x7fca50d55e10>: None,
#               <__main__.Boid at 0x7fca50d55990>: None,
#               <__main__.Boid at 0x7fca50d55f30>: None,
#               <__main__.Boid at 0x7fca50ba8ee0>: None,
#               <__main__.Boid at 0x7fca50ba8eb0>: None,
#               <__main__.Boid at 0x7fca50baaef0>: None,
#               <__main__.Boid at 0x7fca50baae60>: None,
#               <__main__.Boid at 0x7fca50baaf20>: None,
#               <__main__.Boid at 0x7fca50babee0>: None,
#               <__main__.Boid at 0x7fca50babc40>: None,
#               <__main__.Boid at 0x7fca50ba8fd0>: None,
#               <__main__.Boid at 0x7fca50bab100>: None,
#               <__main__.Boid at 0x7fca50bab760>: None,
#               <__main__.Boid at 0x7fca50bab2b0>: None,
#               <__main__.Boid at 0x7fca50bab160>: None,
#               <__main__.Boid at 0x7fca50ba9030>: None,
#               <__main__.Boid at 0x7fca50ba9000>: None,
#               <__main__.Boid at 0x7fca50bab3d0>: None,
#               <__main__.Boid at 0x7fca50bab250>: None,
#               <__main__.Boid at 0x7fca50bab7f0>: None,
#               <__main__.Boid at 0x7fca50baaa70>: None,
#               <__main__.Boid at 0x7fca50bab6a0>: None,
#               <__main__.Boid at 0x7fca50bab490>: None,
#               <__main__.Boid at 0x7fca50babb50>: None,
#               <__main__.Boid at 0x7fca50ba9120>: None,
#               <__main__.Boid at 0x7fca50bab730>: None,
#               <__main__.Boid at 0x7fca50bab430>: None,
#               <__main__.Boid at 0x7fca50baa8c0>: None,
#               <__main__.Boid at 0x7fca50baa680>: None,
#               <__main__.Boid at 0x7fca50babf70>: None,
#               <__main__.Boid at 0x7fca50ba9240>: None,
#               <__main__.Boid at 0x7fca50ba9210>: None,
#               <__main__.Boid at 0x7fca50bab910>: None,
#               <__main__.Boid at 0x7fca50ba91b0>: None,
#               <__main__.Boid at 0x7fca50baa860>: None,
#               <__main__.Boid at 0x7fca50baaaa0>: None,
#               <__main__.Boid at 0x7fca50bab940>: None,
#               <__main__.Boid at 0x7fca50baa560>: None,
#               <__main__.Boid at 0x7fca50baaa40>: None,
#               <__main__.Boid at 0x7fca50baa950>: None,
#               <__main__.Boid at 0x7fca50baa770>: None,
#               <__main__.Boid at 0x7fca50baba00>: None,
#               <__main__.Boid at 0x7fca50baa9b0>: None,
#               <__main__.Boid at 0x7fca50baace0>: None,
#               <__main__.Boid at 0x7fca50baabc0>: None,
#               <__main__.Boid at 0x7fca50babd60>: None,
#               <__main__.Boid at 0x7fca50baa380>: None,
#               <__main__.Boid at 0x7fca50baac50>: None,
#               <__main__.Boid at 0x7fca50baab60>: None,
#               <__main__.Boid at 0x7fca50babdc0>: None,
#               <__main__.Boid at 0x7fca50baad70>: None,
#               <__main__.Boid at 0x7fca50bab070>: None,
#               <__main__.Boid at 0x7fca50bab130>: None,
#               <__main__.Boid at 0x7fca50baaec0>: None,
#               <__main__.Boid at 0x7fca50babfa0>: None,
#               <__main__.Boid at 0x7fca50baae30>: None,
#               <__main__.Boid at 0x7fca50baafe0>: None,
#               <__main__.Boid at 0x7fca50baadd0>: None,
#               <__main__.Boid at 0x7fca50bab010>: None,
#               <__main__.Boid at 0x7fca50bab1c0>: None,
#               <__main__.Boid at 0x7fca50bab340>: None,
#               <__main__.Boid at 0x7fca50babcd0>: None,
#               <__main__.Boid at 0x7fca50baa350>: None,
#               <__main__.Boid at 0x7fca50bab0a0>: None,
#               <__main__.Boid at 0x7fca50bab0d0>: None,
#               <__main__.Boid at 0x7fca50bab3a0>: None,
#               <__main__.Boid at 0x7fca50baa2f0>: None,
#               <__main__.Boid at 0x7fca50bab400>: None,
#               <__main__.Boid at 0x7fca50bab1f0>: None,
#               <__main__.Boid at 0x7fca50bab460>: None,
#               <__main__.Boid at 0x7fca50bab640>: None,
#               <__main__.Boid at 0x7fca50bab370>: None,
#               <__main__.Boid at 0x7fca50bab280>: None,
#               <__main__.Boid at 0x7fca50bab610>: None,
#               <__main__.Boid at 0x7fca50baa590>: None,
#               <__main__.Boid at 0x7fca50bab8e0>: None,
#               <__main__.Boid at 0x7fca50bab820>: None}})

# %%
reconstructed_model = mesa.Model()
column_list = df.columns
agent_list = []
for idx, row in df.iterrows():
    agent = Boid(None, reconstructed_model, None, None, None, None)
    for column in column_list:
        setattr(agent, column, row[column])
    agent_list.append(agent)
agent_list
# Out:
# [<__main__.Boid at 0x7fca50ba8d00>,
#  <__main__.Boid at 0x7fca50b8dcc0>,
#  <__main__.Boid at 0x7fca50b8c700>,
#  <__main__.Boid at 0x7fca50b8c640>,
#  <__main__.Boid at 0x7fca50b8cca0>,
#  <__main__.Boid at 0x7fca50b8dbd0>,
#  <__main__.Boid at 0x7fca50b8c760>,
#  <__main__.Boid at 0x7fca50b8ca30>,
#  <__main__.Boid at 0x7fca50b8cb80>,
#  <__main__.Boid at 0x7fca50b8dc00>,
#  <__main__.Boid at 0x7fca50b8ef20>,
#  <__main__.Boid at 0x7fca50b8cc40>,
#  <__main__.Boid at 0x7fca50b8dc30>,
#  <__main__.Boid at 0x7fca50b8dc60>,
#  <__main__.Boid at 0x7fca50b8dc90>,
#  <__main__.Boid at 0x7fca50b8c400>,
#  <__main__.Boid at 0x7fca50b8db70>,
#  <__main__.Boid at 0x7fca50b8d900>,
#  <__main__.Boid at 0x7fca50b8ca60>,
#  <__main__.Boid at 0x7fca50b8c4c0>,
#  <__main__.Boid at 0x7fca50b8c430>,
#  <__main__.Boid at 0x7fca50b8ee60>,
#  <__main__.Boid at 0x7fca50b8e920>,
#  <__main__.Boid at 0x7fca50b8e6e0>,
#  <__main__.Boid at 0x7fca50b8e620>,
#  <__main__.Boid at 0x7fca50b8e8c0>,
#  <__main__.Boid at 0x7fca50b8e8f0>,
#  <__main__.Boid at 0x7fca50b8e7a0>,
#  <__main__.Boid at 0x7fca50b8ea70>,
#  <__main__.Boid at 0x7fca50b8ea40>,
#  <__main__.Boid at 0x7fca50b8ea10>,
#  <__main__.Boid at 0x7fca50b8e9e0>,
#  <__main__.Boid at 0x7fca50b8e9b0>,
#  <__main__.Boid at 0x7fca50b8e980>,
#  <__main__.Boid at 0x7fca50b8e950>,
#  <__main__.Boid at 0x7fca50b8cb20>,
#  <__main__.Boid at 0x7fca50b8caf0>,
#  <__main__.Boid at 0x7fca50b8d8d0>,
#  <__main__.Boid at 0x7fca50b8c460>,
#  <__main__.Boid at 0x7fca50b8c520>,
#  <__main__.Boid at 0x7fca50b8eef0>,
#  <__main__.Boid at 0x7fca50b8e830>,
#  <__main__.Boid at 0x7fca50b8eda0>,
#  <__main__.Boid at 0x7fca50b8c670>,
#  <__main__.Boid at 0x7fca50b8c880>,
#  <__main__.Boid at 0x7fca50b8cd00>,
#  <__main__.Boid at 0x7fca50b8c850>,
#  <__main__.Boid at 0x7fca50b8ccd0>,
#  <__main__.Boid at 0x7fca50b8c6d0>,
#  <__main__.Boid at 0x7fca50b8c730>,
#  <__main__.Boid at 0x7fca50b8e380>,
#  <__main__.Boid at 0x7fca50b8c790>,
#  <__main__.Boid at 0x7fca50b8d780>,
#  <__main__.Boid at 0x7fca50b8c7c0>,
#  <__main__.Boid at 0x7fca50b8c9a0>,
#  <__main__.Boid at 0x7fca50b8c490>,
#  <__main__.Boid at 0x7fca50b8d8a0>,
#  <__main__.Boid at 0x7fca50b8d990>,
#  <__main__.Boid at 0x7fca50b8fdc0>,
#  <__main__.Boid at 0x7fca50b8c6a0>,
#  <__main__.Boid at 0x7fca50b8c4f0>,
#  <__main__.Boid at 0x7fca50b8cb50>,
#  <__main__.Boid at 0x7fca50b8c3d0>,
#  <__main__.Boid at 0x7fca50b8ca00>,
#  <__main__.Boid at 0x7fca50b8d7b0>,
#  <__main__.Boid at 0x7fca50b8da20>,
#  <__main__.Boid at 0x7fca50b8d810>,
#  <__main__.Boid at 0x7fca50b8dd20>,
#  <__main__.Boid at 0x7fca50b8dd50>,
#  <__main__.Boid at 0x7fca50b8dd80>,
#  <__main__.Boid at 0x7fca50b8de10>,
#  <__main__.Boid at 0x7fca50b8de70>,
#  <__main__.Boid at 0x7fca50b8de40>,
#  <__main__.Boid at 0x7fca50b8dde0>,
#  <__main__.Boid at 0x7fca50b8ddb0>,
#  <__main__.Boid at 0x7fca50b8dea0>,
#  <__main__.Boid at 0x7fca50b8ee00>,
#  <__main__.Boid at 0x7fca50b8edd0>,
#  <__main__.Boid at 0x7fca50b8e200>,
#  <__main__.Boid at 0x7fca50b8e1d0>,
#  <__main__.Boid at 0x7fca50b8e860>,
#  <__main__.Boid at 0x7fca50b8eb00>,
#  <__main__.Boid at 0x7fca50b8e890>,
#  <__main__.Boid at 0x7fca50b8e1a0>,
#  <__main__.Boid at 0x7fca50b8eb60>,
#  <__main__.Boid at 0x7fca50b8e230>,
#  <__main__.Boid at 0x7fca50b8db10>,
#  <__main__.Boid at 0x7fca50964130>,
#  <__main__.Boid at 0x7fca50966bf0>,
#  <__main__.Boid at 0x7fca509643d0>,
#  <__main__.Boid at 0x7fca50967a60>,
#  <__main__.Boid at 0x7fca509659c0>,
#  <__main__.Boid at 0x7fca50967910>,
#  <__main__.Boid at 0x7fca50965a50>,
#  <__main__.Boid at 0x7fca50965f90>,
#  <__main__.Boid at 0x7fca50965e40>,
#  <__main__.Boid at 0x7fca50964700>,
#  <__main__.Boid at 0x7fca50967c70>,
#  <__main__.Boid at 0x7fca50966500>,
#  <__main__.Boid at 0x7fcaaadd12d0>]

# %%
for i in reconstructed_model.agents:
    print(i)
# Out:
# <__main__.Boid object at 0x7fca50ba8d00>
# <__main__.Boid object at 0x7fca50b8dcc0>
# <__main__.Boid object at 0x7fca50b8c700>
# <__main__.Boid object at 0x7fca50b8c640>
# <__main__.Boid object at 0x7fca50b8cca0>
# <__main__.Boid object at 0x7fca50b8dbd0>
# <__main__.Boid object at 0x7fca50b8c760>
# <__main__.Boid object at 0x7fca50b8ca30>
# <__main__.Boid object at 0x7fca50b8cb80>
# <__main__.Boid object at 0x7fca50b8dc00>
# <__main__.Boid object at 0x7fca50b8ef20>
# <__main__.Boid object at 0x7fca50b8cc40>
# <__main__.Boid object at 0x7fca50b8dc30>
# <__main__.Boid object at 0x7fca50b8dc60>
# <__main__.Boid object at 0x7fca50b8dc90>
# <__main__.Boid object at 0x7fca50b8c400>
# <__main__.Boid object at 0x7fca50b8db70>
# <__main__.Boid object at 0x7fca50b8d900>
# <__main__.Boid object at 0x7fca50b8ca60>
# <__main__.Boid object at 0x7fca50b8c4c0>
# <__main__.Boid object at 0x7fca50b8c430>
# <__main__.Boid object at 0x7fca50b8ee60>
# <__main__.Boid object at 0x7fca50b8e920>
# <__main__.Boid object at 0x7fca50b8e6e0>
# <__main__.Boid object at 0x7fca50b8e620>
# <__main__.Boid object at 0x7fca50b8e8c0>
# <__main__.Boid object at 0x7fca50b8e8f0>
# <__main__.Boid object at 0x7fca50b8e7a0>
# <__main__.Boid object at 0x7fca50b8ea70>
# <__main__.Boid object at 0x7fca50b8ea40>
# <__main__.Boid object at 0x7fca50b8ea10>
# <__main__.Boid object at 0x7fca50b8e9e0>
# <__main__.Boid object at 0x7fca50b8e9b0>
# <__main__.Boid object at 0x7fca50b8e980>
# <__main__.Boid object at 0x7fca50b8e950>
# <__main__.Boid object at 0x7fca50b8cb20>
# <__main__.Boid object at 0x7fca50b8caf0>
# <__main__.Boid object at 0x7fca50b8d8d0>
# <__main__.Boid object at 0x7fca50b8c460>
# <__main__.Boid object at 0x7fca50b8c520>
# <__main__.Boid object at 0x7fca50b8eef0>
# <__main__.Boid object at 0x7fca50b8e830>
# <__main__.Boid object at 0x7fca50b8eda0>
# <__main__.Boid object at 0x7fca50b8c670>
# <__main__.Boid object at 0x7fca50b8c880>
# <__main__.Boid object at 0x7fca50b8cd00>
# <__main__.Boid object at 0x7fca50b8c850>
# <__main__.Boid object at 0x7fca50b8ccd0>
# <__main__.Boid object at 0x7fca50b8c6d0>
# <__main__.Boid object at 0x7fca50b8c730>
# <__main__.Boid object at 0x7fca50b8e380>
# <__main__.Boid object at 0x7fca50b8c790>
# <__main__.Boid object at 0x7fca50b8d780>
# <__main__.Boid object at 0x7fca50b8c7c0>
# <__main__.Boid object at 0x7fca50b8c9a0>
# <__main__.Boid object at 0x7fca50b8c490>
# <__main__.Boid object at 0x7fca50b8d8a0>
# <__main__.Boid object at 0x7fca50b8d990>
# <__main__.Boid object at 0x7fca50b8fdc0>
# <__main__.Boid object at 0x7fca50b8c6a0>
# <__main__.Boid object at 0x7fca50b8c4f0>
# <__main__.Boid object at 0x7fca50b8cb50>
# <__main__.Boid object at 0x7fca50b8c3d0>
# <__main__.Boid object at 0x7fca50b8ca00>
# <__main__.Boid object at 0x7fca50b8d7b0>
# <__main__.Boid object at 0x7fca50b8da20>
# <__main__.Boid object at 0x7fca50b8d810>
# <__main__.Boid object at 0x7fca50b8dd20>
# <__main__.Boid object at 0x7fca50b8dd50>
# <__main__.Boid object at 0x7fca50b8dd80>
# <__main__.Boid object at 0x7fca50b8de10>
# <__main__.Boid object at 0x7fca50b8de70>
# <__main__.Boid object at 0x7fca50b8de40>
# <__main__.Boid object at 0x7fca50b8dde0>
# <__main__.Boid object at 0x7fca50b8ddb0>
# <__main__.Boid object at 0x7fca50b8dea0>
# <__main__.Boid object at 0x7fca50b8ee00>
# <__main__.Boid object at 0x7fca50b8edd0>
# <__main__.Boid object at 0x7fca50b8e200>
# <__main__.Boid object at 0x7fca50b8e1d0>
# <__main__.Boid object at 0x7fca50b8e860>
# <__main__.Boid object at 0x7fca50b8eb00>
# <__main__.Boid object at 0x7fca50b8e890>
# <__main__.Boid object at 0x7fca50b8e1a0>
# <__main__.Boid object at 0x7fca50b8eb60>
# <__main__.Boid object at 0x7fca50b8e230>
# <__main__.Boid object at 0x7fca50b8db10>
# <__main__.Boid object at 0x7fca50964130>
# <__main__.Boid object at 0x7fca50966bf0>
# <__main__.Boid object at 0x7fca509643d0>
# <__main__.Boid object at 0x7fca50967a60>
# <__main__.Boid object at 0x7fca509659c0>
# <__main__.Boid object at 0x7fca50967910>
# <__main__.Boid object at 0x7fca50965a50>
# <__main__.Boid object at 0x7fca50965f90>
# <__main__.Boid object at 0x7fca50965e40>
# <__main__.Boid object at 0x7fca50964700>
# <__main__.Boid object at 0x7fca50967c70>
# <__main__.Boid object at 0x7fca50966500>
# <__main__.Boid object at 0x7fcaaadd12d0>

# %% [markdown]
# # Work in Progress

# %%
def get_top_level_data(params_list):
    top_level_data = {}
    for param in params_list:
        top_level_data[param] = cacheable_model.model.__dict__[param]
    return top_level_data
get_top_level_data([ 'speed', 'vision',  'separation'])
# Out:
# {'speed': 5, 'vision': 5, 'separation': 1}

# %%
#model
model.__dict__
# Out:
# {'_seed': 0.9371898361867775,
#  'random': <random.Random at 0x5591affcd950>,
#  '_steps': 0,
#  '_time': 0,
#  'running': True,
#  'schedule': None,
#  'current_id': 0,
#  'agents_': defaultdict(dict,
#              {__main__.Boid: {<__main__.Boid at 0x7fca50d55810>: None,
#                <__main__.Boid at 0x7fca50d55600>: None,
#                <__main__.Boid at 0x7fca50d566e0>: None,
#                <__main__.Boid at 0x7fca50d55a50>: None,
#                <__main__.Boid at 0x7fca50d57070>: None,
#                <__main__.Boid at 0x7fca50d56500>: None,
#                <__main__.Boid at 0x7fca50d55c90>: None,
#                <__main__.Boid at 0x7fca50d562c0>: None,
#                <__main__.Boid at 0x7fca50d56620>: None,
#                <__main__.Boid at 0x7fca50d56470>: None,
#                <__main__.Boid at 0x7fca50d55b40>: None,
#                <__main__.Boid at 0x7fca50d55ae0>: None,
#                <__main__.Boid at 0x7fca50d55ab0>: None,
#                <__main__.Boid at 0x7fca50d560b0>: None,
#                <__main__.Boid at 0x7fca50d56260>: None,
#                <__main__.Boid at 0x7fca50d55630>: None,
#                <__main__.Boid at 0x7fca50d56710>: None,
#                <__main__.Boid at 0x7fca50d55840>: None,
#                <__main__.Boid at 0x7fca50d55690>: None,
#                <__main__.Boid at 0x7fca50d55780>: None,
#                <__main__.Boid at 0x7fca50d555a0>: None,
#                <__main__.Boid at 0x7fca50d55b70>: None,
#                <__main__.Boid at 0x7fca50d557b0>: None,
#                <__main__.Boid at 0x7fca50d55e10>: None,
#                <__main__.Boid at 0x7fca50d55990>: None,
#                <__main__.Boid at 0x7fca50d55f30>: None,
#                <__main__.Boid at 0x7fca50ba8ee0>: None,
#                <__main__.Boid at 0x7fca50ba8eb0>: None,
#                <__main__.Boid at 0x7fca50baaef0>: None,
#                <__main__.Boid at 0x7fca50baae60>: None,
#                <__main__.Boid at 0x7fca50baaf20>: None,
#                <__main__.Boid at 0x7fca50babee0>: None,
#                <__main__.Boid at 0x7fca50babc40>: None,
#                <__main__.Boid at 0x7fca50ba8fd0>: None,
#                <__main__.Boid at 0x7fca50bab100>: None,
#                <__main__.Boid at 0x7fca50bab760>: None,
#                <__main__.Boid at 0x7fca50bab2b0>: None,
#                <__main__.Boid at 0x7fca50bab160>: None,
#                <__main__.Boid at 0x7fca50ba9030>: None,
#                <__main__.Boid at 0x7fca50ba9000>: None,
#                <__main__.Boid at 0x7fca50bab3d0>: None,
#                <__main__.Boid at 0x7fca50bab250>: None,
#                <__main__.Boid at 0x7fca50bab7f0>: None,
#                <__main__.Boid at 0x7fca50baaa70>: None,
#                <__main__.Boid at 0x7fca50bab6a0>: None,
#                <__main__.Boid at 0x7fca50bab490>: None,
#                <__main__.Boid at 0x7fca50babb50>: None,
#                <__main__.Boid at 0x7fca50ba9120>: None,
#                <__main__.Boid at 0x7fca50bab730>: None,
#                <__main__.Boid at 0x7fca50bab430>: None,
#                <__main__.Boid at 0x7fca50baa8c0>: None,
#                <__main__.Boid at 0x7fca50baa680>: None,
#                <__main__.Boid at 0x7fca50babf70>: None,
#                <__main__.Boid at 0x7fca50ba9240>: None,
#                <__main__.Boid at 0x7fca50ba9210>: None,
#                <__main__.Boid at 0x7fca50bab910>: None,
#                <__main__.Boid at 0x7fca50ba91b0>: None,
#                <__main__.Boid at 0x7fca50baa860>: None,
#                <__main__.Boid at 0x7fca50baaaa0>: None,
#                <__main__.Boid at 0x7fca50bab940>: None,
#                <__main__.Boid at 0x7fca50baa560>: None,
#                <__main__.Boid at 0x7fca50baaa40>: None,
#                <__main__.Boid at 0x7fca50baa950>: None,
#                <__main__.Boid at 0x7fca50baa770>: None,
#                <__main__.Boid at 0x7fca50baba00>: None,
#                <__main__.Boid at 0x7fca50baa9b0>: None,
#                <__main__.Boid at 0x7fca50baace0>: None,
#                <__main__.Boid at 0x7fca50baabc0>: None,
#                <__main__.Boid at 0x7fca50babd60>: None,
#                <__main__.Boid at 0x7fca50baa380>: None,
#                <__main__.Boid at 0x7fca50baac50>: None,
#                <__main__.Boid at 0x7fca50baab60>: None,
#                <__main__.Boid at 0x7fca50babdc0>: None,
#                <__main__.Boid at 0x7fca50baad70>: None,
#                <__main__.Boid at 0x7fca50bab070>: None,
#                <__main__.Boid at 0x7fca50bab130>: None,
#                <__main__.Boid at 0x7fca50baaec0>: None,
#                <__main__.Boid at 0x7fca50babfa0>: None,
#                <__main__.Boid at 0x7fca50baae30>: None,
#                <__main__.Boid at 0x7fca50baafe0>: None,
#                <__main__.Boid at 0x7fca50baadd0>: None,
#                <__main__.Boid at 0x7fca50bab010>: None,
#                <__main__.Boid at 0x7fca50bab1c0>: None,
#                <__main__.Boid at 0x7fca50bab340>: None,
#                <__main__.Boid at 0x7fca50babcd0>: None,
#                <__main__.Boid at 0x7fca50baa350>: None,
#                <__main__.Boid at 0x7fca50bab0a0>: None,
#                <__main__.Boid at 0x7fca50bab0d0>: None,
#                <__main__.Boid at 0x7fca50bab3a0>: None,
#                <__main__.Boid at 0x7fca50baa2f0>: None,
#                <__main__.Boid at 0x7fca50bab400>: None,
#                <__main__.Boid at 0x7fca50bab1f0>: None,
#                <__main__.Boid at 0x7fca50bab460>: None,
#                <__main__.Boid at 0x7fca50bab640>: None,
#                <__main__.Boid at 0x7fca50bab370>: None,
#                <__main__.Boid at 0x7fca50bab280>: None,
#                <__main__.Boid at 0x7fca50bab610>: None,
#                <__main__.Boid at 0x7fca50baa590>: None,
#                <__main__.Boid at 0x7fca50bab8e0>: None,
#                <__main__.Boid at 0x7fca50bab820>: None}}),
#  'population': 100,
#  'vision': 5,
#  'speed': 5,
#  'separation': 1,
#  'space': <mesa.space.ContinuousSpace at 0x7fca50d55f90>,
#  'factors': {'cohere': 0.03, 'separate': 0.015, 'match': 0.05}}

# %%
#agent
agent_dict = list(model.agents_.values())
complete_row_data_deserialized = []
for key, val in agent_dict[0].items():
    complete_row_data_deserialized.append(key.__dict__)
complete_row_data_deserialized
# Out:
# [{'unique_id': 0,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([35.1609701 , 19.99947432]),
#   'speed': 5,
#   'direction': array([-0.74732439, -0.66445937]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 1,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([38.79573097, 62.09088494]),
#   'speed': 5,
#   'direction': array([ 0.54882495, -0.8359373 ]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 2,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([61.80900256, 39.8556841 ]),
#   'speed': 5,
#   'direction': array([ 0.82386067, -0.56679237]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50ba9030>]},
#  {'unique_id': 3,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([80.81284511, 91.15839854]),
#   'speed': 5,
#   'direction': array([-0.81831239, -0.57477372]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50d55b70>]},
#  {'unique_id': 4,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([10.23293805, 41.86371728]),
#   'speed': 5,
#   'direction': array([ 0.94038022, -0.34012503]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 5,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([13.96351077,  4.21115639]),
#   'speed': 5,
#   'direction': array([0.07241175, 0.99737482]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50bab490>,
#    <__main__.Boid at 0x7fca50baa860>,
#    <__main__.Boid at 0x7fca50bab460>]},
#  {'unique_id': 6,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([79.83145771, 12.5216323 ]),
#   'speed': 5,
#   'direction': array([-0.34469276, -0.93871556]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50ba9240>,
#    <__main__.Boid at 0x7fca50baa950>,
#    <__main__.Boid at 0x7fca50bab0a0>]},
#  {'unique_id': 7,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([47.89253115,  7.10641491]),
#   'speed': 5,
#   'direction': array([-0.67980145, -0.73339621]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50babd60>]},
#  {'unique_id': 8,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([61.38948976, 66.57486984]),
#   'speed': 5,
#   'direction': array([-0.6971417 ,  0.71693336]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50ba8ee0>,
#    <__main__.Boid at 0x7fca50babf70>]},
#  {'unique_id': 9,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([93.13133623, 16.58976691]),
#   'speed': 5,
#   'direction': array([ 0.87415445, -0.48564802]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50bab8e0>]},
#  {'unique_id': 10,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([67.59005771, 25.87480249]),
#   'speed': 5,
#   'direction': array([ 0.35055812, -0.93654098]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50baaec0>]},
#  {'unique_id': 11,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([28.51316701, 25.89078985]),
#   'speed': 5,
#   'direction': array([-0.70350044, -0.71069483]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50d55690>,
#    <__main__.Boid at 0x7fca50baace0>,
#    <__main__.Boid at 0x7fca50bab340>]},
#  {'unique_id': 12,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([27.22610483, 83.38860442]),
#   'speed': 5,
#   'direction': array([0.6490938 , 0.76070838]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50d56260>,
#    <__main__.Boid at 0x7fca50d555a0>,
#    <__main__.Boid at 0x7fca50bab760>,
#    <__main__.Boid at 0x7fca50babfa0>]},
#  {'unique_id': 13,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([65.05117909, 76.22130824]),
#   'speed': 5,
#   'direction': array([ 0.49807534, -0.86713376]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50bab730>]},
#  {'unique_id': 14,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([22.86589289, 76.03178069]),
#   'speed': 5,
#   'direction': array([-0.99268126, -0.12076387]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50d55ab0>,
#    <__main__.Boid at 0x7fca50d555a0>,
#    <__main__.Boid at 0x7fca50baaef0>,
#    <__main__.Boid at 0x7fca50babc40>,
#    <__main__.Boid at 0x7fca50ba8fd0>,
#    <__main__.Boid at 0x7fca50bab760>,
#    <__main__.Boid at 0x7fca50babfa0>]},
#  {'unique_id': 15,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([17.31652309,  2.6388061 ]),
#   'speed': 5,
#   'direction': array([0.13822015, 0.99040153]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50d56500>,
#    <__main__.Boid at 0x7fca50bab490>,
#    <__main__.Boid at 0x7fca50baa860>]},
#  {'unique_id': 16,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([39.48337682, 94.27979254]),
#   'speed': 5,
#   'direction': array([-0.00999137,  0.99995008]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 17,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([95.15694546, 14.82538268]),
#   'speed': 5,
#   'direction': array([-0.74505203, -0.66700635]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50bab010>]},
#  {'unique_id': 18,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([28.46092965, 26.96284351]),
#   'speed': 5,
#   'direction': array([-0.80468813, -0.59369774]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50baace0>,
#    <__main__.Boid at 0x7fca50bab340>]},
#  {'unique_id': 19,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([93.48209449, 76.39678955]),
#   'speed': 5,
#   'direction': array([-0.93850823,  0.34525688]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50bab100>,
#    <__main__.Boid at 0x7fca50bab1c0>]},
#  {'unique_id': 20,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([24.58193573, 76.04107673]),
#   'speed': 5,
#   'direction': array([-0.99793915, -0.06416735]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50d56260>,
#    <__main__.Boid at 0x7fca50baaef0>,
#    <__main__.Boid at 0x7fca50babc40>,
#    <__main__.Boid at 0x7fca50ba8fd0>,
#    <__main__.Boid at 0x7fca50bab760>]},
#  {'unique_id': 21,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([87.52013281, 91.85434492]),
#   'speed': 5,
#   'direction': array([-0.99956497,  0.02949359]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50babcd0>]},
#  {'unique_id': 22,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([29.12063382, 18.08774868]),
#   'speed': 5,
#   'direction': array([-0.88447126,  0.46659468]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50bab940>]},
#  {'unique_id': 23,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([83.00355344, 36.67582315]),
#   'speed': 5,
#   'direction': array([-0.02613262,  0.99965848]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 24,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([35.10220322, 92.03992916]),
#   'speed': 5,
#   'direction': array([-0.01971389,  0.99980566]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50d56710>,
#    <__main__.Boid at 0x7fca50baba00>]},
#  {'unique_id': 25,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([57.57540662, 37.6495779 ]),
#   'speed': 5,
#   'direction': array([-0.99132028,  0.13146901]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50d566e0>,
#    <__main__.Boid at 0x7fca50ba8eb0>]},
#  {'unique_id': 26,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([58.79391003, 61.49800077]),
#   'speed': 5,
#   'direction': array([-0.84434401,  0.53580144]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 27,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([59.69088605, 40.16646716]),
#   'speed': 5,
#   'direction': array([-0.96921419, -0.24621911]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50d566e0>]},
#  {'unique_id': 28,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([25.01055764, 77.92448333]),
#   'speed': 5,
#   'direction': array([-0.99819608,  0.06003823]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50babc40>,
#    <__main__.Boid at 0x7fca50ba8fd0>]},
#  {'unique_id': 29,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([23.99624323, 38.08666596]),
#   'speed': 5,
#   'direction': array([-0.395296  ,  0.91855379]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 30,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([44.27525741,  9.63684762]),
#   'speed': 5,
#   'direction': array([0.4997171 , 0.86618868]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50ba91b0>]},
#  {'unique_id': 31,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([37.579372  , 83.45582285]),
#   'speed': 5,
#   'direction': array([0.90003062, 0.43582667]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50baaef0>,
#    <__main__.Boid at 0x7fca50ba8fd0>,
#    <__main__.Boid at 0x7fca50baba00>,
#    <__main__.Boid at 0x7fca50baafe0>]},
#  {'unique_id': 32,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([24.12399169, 75.95162273]),
#   'speed': 5,
#   'direction': array([-0.98611112, -0.1660869 ]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50d555a0>,
#    <__main__.Boid at 0x7fca50baaef0>,
#    <__main__.Boid at 0x7fca50ba8fd0>,
#    <__main__.Boid at 0x7fca50bab760>]},
#  {'unique_id': 33,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([25.39167095, 77.68571917]),
#   'speed': 5,
#   'direction': array([-0.98329191, -0.18203579]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50baaef0>,
#    <__main__.Boid at 0x7fca50babc40>]},
#  {'unique_id': 34,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([96.31712097, 76.67942839]),
#   'speed': 5,
#   'direction': array([-0.62557532, -0.78016378]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 35,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([25.16274595, 75.01015499]),
#   'speed': 5,
#   'direction': array([-0.99934758, -0.03611666]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50d56260>,
#    <__main__.Boid at 0x7fca50d555a0>,
#    <__main__.Boid at 0x7fca50baaef0>,
#    <__main__.Boid at 0x7fca50babc40>,
#    <__main__.Boid at 0x7fca50ba8fd0>]},
#  {'unique_id': 36,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([45.13659816, 31.85735749]),
#   'speed': 5,
#   'direction': array([-0.88229971, -0.47068803]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 37,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([16.94245284, 12.26603394]),
#   'speed': 5,
#   'direction': array([0.58023177, 0.81445141]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50d56500>]},
#  {'unique_id': 38,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([58.93460517, 41.09280281]),
#   'speed': 5,
#   'direction': array([ 0.92864407, -0.37097196]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 39,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([27.46517153, 56.04585598]),
#   'speed': 5,
#   'direction': array([-0.80018858, -0.59974848]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50baac50>,
#    <__main__.Boid at 0x7fca50bab280>]},
#  {'unique_id': 40,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([55.2060239 , 72.06186786]),
#   'speed': 5,
#   'direction': array([-0.6230696, -0.7821664]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 41,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([74.21982378, 32.94495778]),
#   'speed': 5,
#   'direction': array([0.83568778, 0.54920482]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50d55b40>,
#    <__main__.Boid at 0x7fca50baaec0>]},
#  {'unique_id': 42,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([81.07461876, 24.04666534]),
#   'speed': 5,
#   'direction': array([-0.68741107,  0.72626856]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50d55c90>,
#    <__main__.Boid at 0x7fca50d56470>,
#    <__main__.Boid at 0x7fca50ba9240>,
#    <__main__.Boid at 0x7fca50baa950>,
#    <__main__.Boid at 0x7fca50bab0a0>]},
#  {'unique_id': 43,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([55.35395464, 17.200958  ]),
#   'speed': 5,
#   'direction': array([-0.83413199,  0.55156489]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 44,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([42.86149558, 82.40347453]),
#   'speed': 5,
#   'direction': array([-0.99993164,  0.01169225]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50bab430>]},
#  {'unique_id': 45,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([15.28432435,  5.95763078]),
#   'speed': 5,
#   'direction': array([0.09238537, 0.99572333]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50d56500>,
#    <__main__.Boid at 0x7fca50d55630>]},
#  {'unique_id': 46,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([11.91535601, 53.4404523 ]),
#   'speed': 5,
#   'direction': array([ 0.38415341, -0.92326928]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 47,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([59.56389122, 94.67810681]),
#   'speed': 5,
#   'direction': array([-0.99221797,  0.12451305]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 48,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([63.6635687 , 78.00094236]),
#   'speed': 5,
#   'direction': array([ 0.51775828, -0.85552695]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 49,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([44.94206028, 81.38440389]),
#   'speed': 5,
#   'direction': array([-0.63722268, -0.77067974]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 50,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([24.84687006, 45.90703089]),
#   'speed': 5,
#   'direction': array([ 0.16055453, -0.98702697]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 51,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([87.74613291, 74.58766334]),
#   'speed': 5,
#   'direction': array([-0.55051215,  0.83482715]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 52,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([72.37031042, 68.48451865]),
#   'speed': 5,
#   'direction': array([0.62230005, 0.78277879]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 53,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([76.99474409, 21.81912139]),
#   'speed': 5,
#   'direction': array([-0.75314019,  0.65786005]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50baa950>,
#    <__main__.Boid at 0x7fca50bab0a0>]},
#  {'unique_id': 54,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([88.04861533, 83.3804535 ]),
#   'speed': 5,
#   'direction': array([ 0.76458888, -0.64451831]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 55,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([83.06294803, 35.53998819]),
#   'speed': 5,
#   'direction': array([-0.99644998,  0.08418692]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 56,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([42.8969554 ,  6.78186645]),
#   'speed': 5,
#   'direction': array([0.12504044, 0.99215165]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 57,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([9.25734676, 0.93924089]),
#   'speed': 5,
#   'direction': array([-0.62484098,  0.78075205]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50bab490>]},
#  {'unique_id': 58,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([36.45978162, 76.29824271]),
#   'speed': 5,
#   'direction': array([-0.70262556,  0.71155978]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50baa9b0>]},
#  {'unique_id': 59,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([33.56542846, 18.74550267]),
#   'speed': 5,
#   'direction': array([ 0.97119608, -0.2382817 ]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 60,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([11.19528174, 40.19793311]),
#   'speed': 5,
#   'direction': array([0.63634259, 0.77140658]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50bab0d0>]},
#  {'unique_id': 61,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([69.68174628, 38.00085046]),
#   'speed': 5,
#   'direction': array([-0.16397933, -0.98646378]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 62,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([80.58696641, 16.3704913 ]),
#   'speed': 5,
#   'direction': array([-0.29821006, -0.95450027]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50d55c90>,
#    <__main__.Boid at 0x7fca50bab7f0>,
#    <__main__.Boid at 0x7fca50ba9240>,
#    <__main__.Boid at 0x7fca50bab0a0>]},
#  {'unique_id': 63,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([81.67770091, 50.77280193]),
#   'speed': 5,
#   'direction': array([-0.37503792, -0.92700947]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 64,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([37.27147877, 85.42676511]),
#   'speed': 5,
#   'direction': array([0.80139802, 0.59813144]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50babee0>,
#    <__main__.Boid at 0x7fca50ba8fd0>,
#    <__main__.Boid at 0x7fca50baafe0>]},
#  {'unique_id': 65,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([35.95405073, 79.06188098]),
#   'speed': 5,
#   'direction': array([-0.66437858,  0.74739621]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50baaaa0>,
#    <__main__.Boid at 0x7fca50baadd0>]},
#  {'unique_id': 66,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([27.69585633, 34.40150757]),
#   'speed': 5,
#   'direction': array([-0.99693328,  0.07825618]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 67,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([41.54760673, 95.88704029]),
#   'speed': 5,
#   'direction': array([-0.99074271,  0.13575305]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 68,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([50.13060929, 11.25540778]),
#   'speed': 5,
#   'direction': array([0.08516196, 0.99636712]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50d562c0>,
#    <__main__.Boid at 0x7fca50bab820>]},
#  {'unique_id': 69,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([91.36418426, 76.08478256]),
#   'speed': 5,
#   'direction': array([-0.47859485, -0.87803586]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50d55780>,
#    <__main__.Boid at 0x7fca50bab100>,
#    <__main__.Boid at 0x7fca50babcd0>]},
#  {'unique_id': 70,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([26.02756555, 57.30225721]),
#   'speed': 5,
#   'direction': array([-0.66488899, -0.74694219]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 71,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([38.65465991, 29.53715533]),
#   'speed': 5,
#   'direction': array([-0.26802551, -0.96341182]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 72,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([14.73157333, 89.19550692]),
#   'speed': 5,
#   'direction': array([-0.83665992,  0.54772273]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 73,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([67.22960582,  3.87090602]),
#   'speed': 5,
#   'direction': array([-0.36881311, -0.92950357]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50baa590>]},
#  {'unique_id': 74,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([87.12738521, 49.37846787]),
#   'speed': 5,
#   'direction': array([0.51754818, 0.85565407]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 75,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([28.24384729, 21.00993454]),
#   'speed': 5,
#   'direction': array([-0.76156104, -0.64809319]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50d55ae0>,
#    <__main__.Boid at 0x7fca50d55690>]},
#  {'unique_id': 76,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([72.46705438, 31.74176488]),
#   'speed': 5,
#   'direction': array([ 0.91897081, -0.39432556]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 77,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([27.51142004, 83.69258527]),
#   'speed': 5,
#   'direction': array([0.59902415, 0.80073096]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50d55ab0>,
#    <__main__.Boid at 0x7fca50d56260>,
#    <__main__.Boid at 0x7fca50d555a0>,
#    <__main__.Boid at 0x7fca50baaef0>,
#    <__main__.Boid at 0x7fca50ba8fd0>,
#    <__main__.Boid at 0x7fca50bab760>]},
#  {'unique_id': 78,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([2.41036825, 9.21963671]),
#   'speed': 5,
#   'direction': array([ 0.5944635 , -0.80412259]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50d55840>,
#    <__main__.Boid at 0x7fca50bab010>,
#    <__main__.Boid at 0x7fca50bab640>]},
#  {'unique_id': 79,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([33.07390433, 84.66920249]),
#   'speed': 5,
#   'direction': array([-0.84507478,  0.53464813]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50babee0>,
#    <__main__.Boid at 0x7fca50baba00>]},
#  {'unique_id': 80,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([41.88524461, 79.55554788]),
#   'speed': 5,
#   'direction': array([-0.9968037 ,  0.07988977]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50bab6a0>]},
#  {'unique_id': 81,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([98.09142822, 15.14514232]),
#   'speed': 5,
#   'direction': array([-0.85913318,  0.51175207]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50baae30>]},
#  {'unique_id': 82,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([ 0.98761067, 73.34925648]),
#   'speed': 5,
#   'direction': array([-0.53152256, -0.84704413]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 83,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([27.01872604, 32.7313686 ]),
#   'speed': 5,
#   'direction': array([-0.95803196, -0.2866614 ]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50baace0>]},
#  {'unique_id': 84,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([92.34076793, 84.71674254]),
#   'speed': 5,
#   'direction': array([-0.05554702, -0.99845607]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 85,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([66.88143933, 22.21812318]),
#   'speed': 5,
#   'direction': array([-0.92037617,  0.39103414]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 86,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([79.80064221, 14.12269263]),
#   'speed': 5,
#   'direction': array([-0.35868647, -0.9334581 ]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50baa950>]},
#  {'unique_id': 87,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([ 4.23060229, 35.48700438]),
#   'speed': 5,
#   'direction': array([-0.99831297, -0.05806219]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50baa560>]},
#  {'unique_id': 88,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([94.8566928,  5.7980382]),
#   'speed': 5,
#   'direction': array([-0.99996021, -0.00892025]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50baae30>]},
#  {'unique_id': 89,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([76.3459425 , 14.02761529]),
#   'speed': 5,
#   'direction': array([-0.17691013,  0.98422701]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50d55c90>]},
#  {'unique_id': 90,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([21.3355109 , 58.96276711]),
#   'speed': 5,
#   'direction': array([-0.81803805,  0.57516411]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50ba9000>,
#    <__main__.Boid at 0x7fca50baac50>]},
#  {'unique_id': 91,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([99.77399564, 24.30465885]),
#   'speed': 5,
#   'direction': array([-0.26344515, -0.96467438]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 92,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([5.53776577, 0.23791001]),
#   'speed': 5,
#   'direction': array([-0.79909383,  0.60120632]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50baa860>]},
#  {'unique_id': 93,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([95.88453391, 13.13052379]),
#   'speed': 5,
#   'direction': array([-0.49025404,  0.87157958]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50baae30>,
#    <__main__.Boid at 0x7fca50bab3a0>]},
#  {'unique_id': 94,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([23.46153185, 84.75351512]),
#   'speed': 5,
#   'direction': array([-0.9940728 , -0.10871648]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50baafe0>]},
#  {'unique_id': 95,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([34.26374999, 57.72817675]),
#   'speed': 5,
#   'direction': array([-0.7615181 ,  0.64814364]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 96,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([69.42021067, 58.24074533]),
#   'speed': 5,
#   'direction': array([-0.85710438, -0.51514277]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 97,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([69.89356058,  5.9113415 ]),
#   'speed': 5,
#   'direction': array([0.0633869 , 0.99798903]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': []},
#  {'unique_id': 98,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([88.72109019, 16.14148215]),
#   'speed': 5,
#   'direction': array([-0.18071103, -0.98353623]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50d56470>]},
#  {'unique_id': 99,
#   'model': <__main__.BoidFlockers at 0x7fca50d559f0>,
#   'pos': array([45.82839099,  9.4244078 ]),
#   'speed': 5,
#   'direction': array([-0.94890367,  0.31556587]),
#   'vision': 5,
#   'separation': 1,
#   'cohere_factor': 0.03,
#   'separate_factor': 0.015,
#   'match_factor': 0.05,
#   'neighbors': [<__main__.Boid at 0x7fca50d562c0>,
#    <__main__.Boid at 0x7fca50babd60>]}]

# %%
def get_agent_data(self, parameters):
    agent_dict = list(self.model.agents_.values())
    complete_row_data_deserialized = []
    for key, val in agent_dict[0].items():
        complete_row_data_deserialized.append(key.__dict__)
    boids_data = []
    for row_record in complete_row_data_deserialized:
        clean_row_data = {}
        for param in parameters:
            clean_row_data[param] = row_record[param]
        boids_data.append(clean_row_data)
    boids_table = pa.Table.from_pylist(boids_data)
    padding = len(str(self._total_steps)) - 1
    print(self.model._steps)
    filename = f"{self.cache_file_path}/grid_data_{self.model._steps:0{padding}}.parquet"
    print(filename)
    pq.write_table(boids_table, filename)
    return boids_data

# %%
import matplotlib.pyplot as plt
def draw_boids(model):
    x_vals = []
    y_vals = []
    for boid in model.agents:
        x, y = boid.pos
        x_vals.append(x)
        y_vals.append(y)
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111)
    ax.scatter(x_vals, y_vals)

# %%
draw_boids(model_a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 draw_boids(model_a)
#
# NameError: name 'model_a' is not defined

# %%
from mesa.visualization import SolaraViz#, make_space_matplotlib

def boid_draw(agent):
    return {"color": "tab:red"}


model_params = {
    "population": 100,
    "width": 100,
    "height": 100,
    "speed": 5,
    "vision": 10,
    "separation": 2,
}

model = BoidFlockers(100, 100, 100, 5, 10, 2)

page = SolaraViz(
    model_class=BoidFlockers,
    model_params=model_params,
    measures=[],
    name="BoidFlockers",
    agent_portrayal=boid_draw,
)

# %%
page
# Out:
# Cannot show ipywidgets in text
